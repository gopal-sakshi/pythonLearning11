# %%
# %run package_spacy25.py
# Out:
# text23 --->  Last ____entity type____  DATE
# text23 --->  Thursday ____entity type____  DATE
# text23 --->  , ____entity type____
# text23 --->  Manchester ____entity type____  GPE
# text23 --->  United ____entity type____  GPE
# text23 --->  defeated ____entity type____
# text23 --->  AC ____entity type____  ORG
# text23 --->  Milan ____entity type____  ORG
# text23 --->  at ____entity type____
# text23 --->  San ____entity type____  GPE
# text23 --->  Siro ____entity type____  GPE
# text23 --->  . ____entity type____
# __cT__ Manchester United __rt__ United __dep__ nsubj __text__ defeated
# __cT__ AC Milan __rt__ Milan __dep__ dobj __text__ defeated
# __cT__ San Siro __rt__ Siro __dep__ pobj __text__ at
# Last amod Thursday PROPN []
# Thursday npadvmod defeated VERB [Last]
# , punct defeated VERB []
# Manchester compound United PROPN []
# United nsubj defeated VERB [Manchester]
# defeated ROOT defeated VERB [Thursday, ,, United, Milan, at, .]
# AC compound Milan PROPN []
# ...
